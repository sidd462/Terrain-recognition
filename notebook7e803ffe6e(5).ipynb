# %%
import os
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import keras
print("keras version: ", keras.__version__)

import tensorflow as tf
print("tensoflow version: ", tf.__version__)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_9869/3144071719.py", line 3, in <module>
#     from matplotlib import pyplot as plt
# ModuleNotFoundError: No module named 'matplotlib'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1115, in get_records
#     style = stack_data.style_with_executing_node(style, self._tb_highlight)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/stack_data/core.py", line 424, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 91, in __new__
#     ndef[4] = colorformat(styledef[3:])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 58, in colorformat
#     assert False, "wrong color format %r" % text
# AssertionError: wrong color format 'ansiyellow'

# %%
import random
random.seed(42)
tf.random.set_seed(42)
np.random.seed(42)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_9869/2053465271.py", line 3, in <module>
#     tf.random.set_seed(42)
#     ^^
# NameError: name 'tf' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1115, in get_records
#     style = stack_data.style_with_executing_node(style, self._tb_highlight)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/stack_data/core.py", line 424, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 91, in __new__
#     ndef[4] = colorformat(styledef[3:])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 58, in colorformat
#     assert False, "wrong color format %r" % text
# AssertionError: wrong color format 'ansiyellow'

# %%
train = "data/1-Kaggle-4/1-Train"
test = "data/1-Kaggle-4/2-Test"
val = "data/1-Kaggle-4/2-Test"

# %%
image_path = "/kaggle/input/terrain-recognition/Data Main/train/Rocky/Rocky (1)_0_25.png"
img = cv2.imread(image_path, 0)
img.shape
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_9869/2709436531.py", line 2, in <module>
#     img = cv2.imread(image_path, 0)
#           ^^^
# NameError: name 'cv2' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1115, in get_records
#     style = stack_data.style_with_executing_node(style, self._tb_highlight)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/stack_data/core.py", line 424, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 91, in __new__
#     ndef[4] = colorformat(styledef[3:])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 58, in colorformat
#     assert False, "wrong color format %r" % text
# AssertionError: wrong color format 'ansiyellow'

# %%
train_names = []
train_names = [f for f in sorted(os.listdir(train))]

print(len(train_names))
# Out:
# 4

# %%
test_names = []
test_names = [f for f in sorted(os.listdir(test))]

print(len(test_names))
# Out:
# 4

# %%
val_names = []
val_names = [f for f in sorted(os.listdir(val))]

print(len(val_names))
# Out:
# 4

# %%
print("Categories:")
for i in train_names:
    print(i)
# Out:
# Categories:
# 1-Grassy
# 2-Marshy
# 3-Rocky
# 4-Sandy

# %%
category_dict1 = {}
images_per_category_dict1 = {}
category_images_path_dict1 = {}

total_images = 0

for i in range(len(train_names)):
    folder_path = train + '/' + str(train_names[i])
    category_dict1[i] = train_names[i]
    image_names = [img for img in sorted(os.listdir(folder_path))]
    images_per_category_dict1[i] = len(image_names)
    category_images_path_dict1[i] = image_names
    print('%s: %d' %(train_names[i], images_per_category_dict1[i]))
    total_images += images_per_category_dict1[i]
    
print('Total images in training data: %d' %(total_images))
# Out:
# 1-Grassy: 8512
# 2-Marshy: 7727
# 3-Rocky: 7668
# 4-Sandy: 7664
# Total images in training data: 31571

# %%
category_dict2 = {}
images_per_category_dict2 = {}
category_images_path_dict2 = {}

total_images = 0

for i in range(len(test_names)):
    folder_path = test + '/' + str(test_names[i])
    category_dict2[i] = test_names[i]

    image_names = [img for img in sorted(os.listdir(folder_path))]
    
    images_per_category_dict2[i] = len(image_names)
    category_images_path_dict2[i] = image_names
    
    print('%s: %d' %(test_names[i], images_per_category_dict2[i]))
    total_images += images_per_category_dict2[i]
    
print('Total images in validation data: %d' %(total_images))
# Out:
# 1-Grassy: 1824
# 2-Marshy: 1657
# 3-Rocky: 1644
# 4-Sandy: 1644
# Total images in validation data: 6769

# %%
category_dict3 = {}
images_per_category_dict3 = {}
category_images_path_dict3 = {}

total_images = 0

for i in range(len(val_names)):
    folder_path = test + '/' + str(val_names[i])
    category_dict3[i] = val_names[i]

    image_names = [img for img in sorted(os.listdir(folder_path))]
    
    images_per_category_dict3[i] = len(image_names)
    category_images_path_dict3[i] = image_names
    
    print('%s: %d' %(val_names[i], images_per_category_dict3[i]))
    total_images += images_per_category_dict3[i]
    
print('Total images in validation data: %d' %(total_images))
# Out:
# 1-Grassy: 1824
# 2-Marshy: 1657
# 3-Rocky: 1644
# 4-Sandy: 1644
# Total images in validation data: 6769

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255,)

test_datagen = ImageDataGenerator(rescale=1./255, validation_split= 0.2)

train_generator = train_datagen.flow_from_directory(
        train,
        batch_size=8,
        target_size=(128, 128),
        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
        val,
        batch_size=8,
        target_size=(128, 128),
        class_mode='categorical')
# Out:
# 2023-10-17 17:44:01.114278: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-17 17:44:01.628011: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found 31571 images belonging to 4 classes.
# Found 6769 images belonging to 4 classes.

# %%
from keras.models import Sequential
from keras import layers
# model = Sequential()
# model.add(layers.Conv2D(128, (5, 5), activation = 'relu', input_shape = (128, 128, 3)))
# model.add(layers.Conv2D(128, (3,3), activation='relu'))
# model.add(layers.MaxPooling2D(pool_size = (2, 2)))
# model.add(layers.Dropout(0.25))
          
# model.add(layers.Conv2D(256, (3, 3), activation = 'relu'))
# model.add(layers.Conv2D(256, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D(pool_size = (2, 2)))
# model.add(layers.Dropout(0.25))
# model.add(layers.Flatten())                   
# model.add(layers.Dense(512, activation = 'relu'))
# model.add(layers.Dropout(0.5))

# model.add(layers.Dense(4, activation = 'softmax'))

# model = tf.keras.applications.efficientnet.EfficientNetB7(include_top=False, weights='imagenet')

# %%
model.summary()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_9869/3470139634.py", line 1, in <module>
#     model.summary()
#     ^^^^^
# NameError: name 'model' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1115, in get_records
#     style = stack_data.style_with_executing_node(style, self._tb_highlight)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/stack_data/core.py", line 424, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 91, in __new__
#     ndef[4] = colorformat(styledef[3:])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 58, in colorformat
#     assert False, "wrong color format %r" % text
# AssertionError: wrong color format 'ansiyellow'

# %%
model.trainable = False
model1 = Sequential([
    model,
    layers.GlobalMaxPooling2D(),
    layers.Dense(512, activation  ="relu"),
    layers.Dense(4, activation = "softmax")
])
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_9869/3851805759.py", line 1, in <module>
#     model.trainable = False
#     ^^^^^
# NameError: name 'model' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1115, in get_records
#     style = stack_data.style_with_executing_node(style, self._tb_highlight)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/stack_data/core.py", line 424, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 91, in __new__
#     ndef[4] = colorformat(styledef[3:])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 58, in colorformat
#     assert False, "wrong color format %r" % text
# AssertionError: wrong color format 'ansiyellow'

# %%
model1.summary()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_9869/1054623878.py", line 1, in <module>
#     model1.summary()
#     ^^^^^^
# NameError: name 'model1' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1115, in get_records
#     style = stack_data.style_with_executing_node(style, self._tb_highlight)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/stack_data/core.py", line 424, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 91, in __new__
#     ndef[4] = colorformat(styledef[3:])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 58, in colorformat
#     assert False, "wrong color format %r" % text
# AssertionError: wrong color format 'ansiyellow'

# %%
from keras import optimizers
model1.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(), metrics=['accuracy'])
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_9869/3534434978.py", line 2, in <module>
#     model1.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(), metrics=['accuracy'])
#     ^^^^^^
# NameError: name 'model1' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1115, in get_records
#     style = stack_data.style_with_executing_node(style, self._tb_highlight)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/stack_data/core.py", line 424, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 91, in __new__
#     ndef[4] = colorformat(styledef[3:])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 58, in colorformat
#     assert False, "wrong color format %r" % text
# AssertionError: wrong color format 'ansiyellow'

# %%
EarlyStopping_1=tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 4, verbose = 1)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_9869/3991112978.py", line 1, in <module>
#     EarlyStopping_1=tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 4, verbose = 1)
#                     ^^
# NameError: name 'tf' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1115, in get_records
#     style = stack_data.style_with_executing_node(style, self._tb_highlight)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/stack_data/core.py", line 424, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 91, in __new__
#     ndef[4] = colorformat(styledef[3:])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sidd462/miniconda3/lib/python3.11/site-packages/pygments/style.py", line 58, in colorformat
#     assert False, "wrong color format %r" % text
# AssertionError: wrong color format 'ansiyellow'

# %%
# history = model1.fit(train_generator, epochs = 50, validation_data = test_generator, verbose = 1, callbacks = EarlyStopping_1)

# %%
# val_acc = history.history["val_accuracy"]
# acc = history.history["accuracy"]

# plt.plot(acc)
# plt.plot(val_acc)
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')

# %%
# history.history

# %%
# import matplotlib.pyplot as plt


# val_acc = history.history["val_loss"]
# acc = history.history["loss"]

# plt.plot(acc, color='blue')
# plt.plot(val_acc, color='red')
# plt.legend(['loss', 'val_loss'], loc='upper left')
# plt.title('Model Loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.show()

# %%
from vit_keras import vit
import tensorflow as tf

# Create the ViT model
def create_vit_model():
    vit_model = vit.vit_l32(
        image_size=128,
        activation='softmax',
        pretrained=True,
        include_top=True,
        pretrained_top=False,
        classes=4
    )
    
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(128, 128, 3)),
        vit_model,
        tf.keras.layers.Dense(4, activation='softmax')
    ])
    
    return model

# Model Configuration
input_shape = (128, 128, 3)  # Match with your input shape
num_classes = 4  # Number of output classes

# Create and compile the model
model = create_vit_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Model Training
# Assuming train_generator and test_generator are already defined in your code
model.fit(train_generator, epochs=50, validation_data=test_generator)
# Out:
# /home/sidd462/miniconda3/lib/python3.11/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2023-10-17 17:44:04.643101: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-17 17:44:04.662215: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-17 17:44:04.662273: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-17 17:44:04.664151: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-17 17:44:04.664274: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-17 17:44:04.664310: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-17 17:44:05.355767: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-17 17:44:05.355831: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-17 17:44:05.355837: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1726] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-10-17 17:44:05.355857: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-17 17:44:05.355878: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9386 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# /home/sidd462/miniconda3/lib/python3.11/site-packages/vit_keras/utils.py:81: UserWarning: Resizing position embeddings from 12, 12 to 4, 4
#   warnings.warn(
# Epoch 1/50
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import tensorflow as tf

tf.config.experimental.list_physical_devices()
# Out:
# 2023-10-17 17:37:11.473725: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-17 17:37:12.928541: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-10-17 17:37:14.549868: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-17 17:37:14.841895: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-17 17:37:14.841945: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
